# %% [markdown]
# Download and Extract dataset

# %% [markdown]
# Dataset Source: https://challenge2018.isic-archive.com/task3/

# %%
# !wget -q https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task3_Training_Input.zip
# !unzip -q ISIC2018_Task3_Training_Input.zip
# !rm ISIC2018_Task3_Training_Input.zip
# !wget -q https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task3_Training_GroundTruth.zip
# !unzip -q ISIC2018_Task3_Training_GroundTruth.zip
# !rm ISIC2018_Task3_Training_GroundTruth.zip
# !wget -q https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task3_Validation_Input.zip
# !unzip -q ISIC2018_Task3_Validation_Input.zip
# !rm ISIC2018_Task3_Validation_Input.zip
# !wget -q https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task3_Validation_GroundTruth.zip
# !unzip -q ISIC2018_Task3_Validation_GroundTruth.zip
# !rm ISIC2018_Task3_Validation_GroundTruth.zip
# !rm */*.txt

# %%
from tensorflow import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
import keras.layers
import keras.models
import sklearn.model_selection
import sklearn.metrics
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
from keras import backend as K
import shutil
import matplotlib.pyplot as plt
import os
import cv2
# %matplotlib inline

# %% [markdown]
# Reading Training and validation Data

# %%
df_train = pd.read_csv("ISIC2018_Task3_Training_GroundTruth/ISIC2018_Task3_Training_GroundTruth.csv")
df_val = pd.read_csv("ISIC2018_Task3_Validation_GroundTruth/ISIC2018_Task3_Validation_GroundTruth.csv")

# %% [markdown]
# Create Directories to store Training and Validation images

# %%
# !mkdir Train Train/MEL Train/NV Train/BCC Train/AKIEC Train/BKL Train/DF Train/VASC
# !mkdir Validation Validation/MEL Validation/NV Validation/BCC Validation/AKIEC Validation/BKL Validation/DF Validation/VASC

# %% [markdown]
# Sort Training and Validation images into directories earlier created based on class labels from the given .csv files

# %%
for i in range(len(df_train)):
  if df_train["MEL"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train/MEL")
  if df_train["NV"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train/NV")
  if df_train["BCC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train/BCC")
  if df_train["AKIEC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train/AKIEC")
  if df_train["BKL"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train/BKL")
  if df_train["DF"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train/DF")
  if df_train["VASC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train/VASC")

for i in range(len(df_val)):
  if df_val["MEL"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation/MEL")
  if df_val["NV"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation/NV")
  if df_val["BCC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation/BCC")
  if df_val["AKIEC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation/AKIEC")
  if df_val["BKL"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation/BKL")
  if df_val["DF"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation/DF")
  if df_val["VASC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation/VASC")

# %% [markdown]
# Display resized examples from each class

# %%
class_types = ['MEL', 'NV', 'BCC', 'AKIEC', 'BKL', 'DF', 'VASC']
for class_type in class_types:
  path_of_class = '/content/Train/' + class_type + '/'
  file_list = os.listdir(path_of_class)
  img_list = []
  for i in range(5):
    image = cv2.imread(path_of_class + file_list[i], cv2.IMREAD_COLOR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (100,75))
    img_list.append(image)
  f, axarr = plt.subplots(1,5, figsize=(75, 100))
  print("Class : ", class_type)
  for i in range(5):
    axarr[i].imshow(img_list[i])
  plt.show()
# Out:
# Class :  MEL
# Class :  NV
# Class :  BCC
# Class :  AKIEC
# Class :  BKL
# Class :  DF
# Class :  VASC

# %% [markdown]
# Read Dataset and augment images. We would use 20% of images from training set as test set

# %%
datagen = ImageDataGenerator(rescale=1./255,
        rotation_range=10,
        zoom_range = 0.1,
        width_shift_range=0.1,
        height_shift_range=0.1,
        validation_split=0.2) 

datagen2 = ImageDataGenerator(rescale=1./255,
        rotation_range=10,
        zoom_range = 0.1,
        width_shift_range=0.1,
        height_shift_range=0.1)

traingenerator = datagen.flow_from_directory(
        'Train',
        target_size=(75, 100),
        seed=0,
        batch_size=100,
        subset='training',
        class_mode='categorical')

testgenerator = datagen.flow_from_directory(
        'Train',
        target_size=(75, 100),
        seed=0,
        batch_size=100,
        subset='validation',
        class_mode='categorical')

valgenerator = datagen2.flow_from_directory(
        'Validation',
        target_size=(75, 100),
        seed=0,
        batch_size=100,
        class_mode='categorical')
# Out:
# Found 8015 images belonging to 7 classes.
# Found 2000 images belonging to 7 classes.
# Found 193 images belonging to 7 classes.

# %% [markdown]
# Count datapoints (images) from each class

# %%
class_freq = np.unique(traingenerator.classes, return_counts=True)
class_index = traingenerator.class_indices
COUNT_AKIEC, COUNT_BCC, COUNT_BKL, COUNT_DF, COUNT_MEL, COUNT_NV, COUNT_VASC = class_freq[1]
sns.countplot(traingenerator.classes)
print(class_index)
# Out:
# {'AKIEC': 0, 'BCC': 1, 'BKL': 2, 'DF': 3, 'MEL': 4, 'NV': 5, 'VASC': 6}
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# As we can see that our data is highly imbalanced, expecially when classes NV and DF are considered

# %%
print("Class name   no. of samples")
for c_name, freq in zip(class_index.keys(), class_freq[1]):
  print("{: >8} {: >10}".format(c_name, freq))
# Out:
# Class name   no. of samples
#    AKIEC        262
#      BCC        412
#      BKL        880
#       DF         92
#      MEL        891
#       NV       5364
#     VASC        114

# %% [markdown]
# Since our dataset is highly imbalanced, we will use "weighted" approach to training, where we would use inverse of ratios of total samples of a class to total number of samples in the dataset

# %%
TRAIN_IMG_COUNT = len(traingenerator.classes)
weight_for_0 = (1 / COUNT_AKIEC)*(TRAIN_IMG_COUNT)/100
weight_for_1 = (1 / COUNT_BCC)*(TRAIN_IMG_COUNT)/100
weight_for_2 = (1 / COUNT_BKL)*(TRAIN_IMG_COUNT)/100
weight_for_3 = (1 / COUNT_DF)*(TRAIN_IMG_COUNT)/100
weight_for_4 = (1 / COUNT_MEL)*(TRAIN_IMG_COUNT)/100
weight_for_5 = (1 / COUNT_NV)*(TRAIN_IMG_COUNT)/100
weight_for_6 = (1 / COUNT_VASC)*(TRAIN_IMG_COUNT)/100
class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3, 4: weight_for_4, 5: weight_for_5, 6: weight_for_6}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
print('Weight for class 3: {:.2f}'.format(weight_for_3))
print('Weight for class 4: {:.2f}'.format(weight_for_4))
print('Weight for class 5: {:.2f}'.format(weight_for_5))
print('Weight for class 6: {:.2f}'.format(weight_for_6))
# Out:
# Weight for class 0: 0.31
# Weight for class 1: 0.19
# Weight for class 2: 0.09
# Weight for class 3: 0.87
# Weight for class 4: 0.09
# Weight for class 5: 0.01
# Weight for class 6: 0.70

# %%
def create_model():
  model = tf.keras.models.Sequential()
  model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(75, 100, 3)))
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
  model.add(tf.keras.layers.BatchNormalization())

  model.add(tf.keras.layers.Flatten())
  model.add(tf.keras.layers.Dense(units=2048, activation='relu'))
  model.add(tf.keras.layers.Dropout(0.1))
  model.add(tf.keras.layers.Dense(units=256, activation='relu'))
  model.add(tf.keras.layers.Dense(units=7, activation='softmax'))

  model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', tf.metrics.Precision(), tf.metrics.Recall(), tf.metrics.AUC(), tf.metrics.AUC(curve='PR')])

  return model

# %% [markdown]
# Minimize val_loss

# %%
model_val_loss = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=8, mode='min',restore_best_weights=True, verbose=1)
history_val_loss = model_val_loss.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 81/81 [==============================] - 158s 2s/step - loss: 0.8817 - accuracy: 0.6822 - precision: 0.8021 - recall: 0.5829 - auc: 0.9342 - auc_1: 0.7780 - val_loss: 1.6538 - val_accuracy: 0.1140 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7620 - val_auc_1: 0.2590
# Epoch 2/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.7634 - accuracy: 0.7173 - precision: 0.8295 - recall: 0.6228 - auc: 0.9509 - auc_1: 0.8209 - val_loss: 2.2053 - val_accuracy: 0.1140 - val_precision: 0.1146 - val_recall: 0.1140 - val_auc: 0.6822 - val_auc_1: 0.1972
# Epoch 3/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.7145 - accuracy: 0.7340 - precision: 0.8239 - recall: 0.6509 - auc: 0.9565 - auc_1: 0.8360 - val_loss: 1.9946 - val_accuracy: 0.1399 - val_precision: 0.1220 - val_recall: 0.0259 - val_auc: 0.6261 - val_auc_1: 0.1789
# Epoch 4/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.6829 - accuracy: 0.7465 - precision: 0.8310 - recall: 0.6656 - auc: 0.9607 - auc_1: 0.8478 - val_loss: 1.1955 - val_accuracy: 0.6218 - val_precision: 0.8119 - val_recall: 0.4249 - val_auc: 0.8756 - val_auc_1: 0.6766
# Epoch 5/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.6821 - accuracy: 0.7497 - precision: 0.8290 - recall: 0.6640 - auc: 0.9606 - auc_1: 0.8475 - val_loss: 0.9968 - val_accuracy: 0.6218 - val_precision: 0.7095 - val_recall: 0.5440 - val_auc: 0.9168 - val_auc_1: 0.7175
# Epoch 6/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.6477 - accuracy: 0.7622 - precision: 0.8353 - recall: 0.6886 - auc: 0.9644 - auc_1: 0.8593 - val_loss: 0.8999 - val_accuracy: 0.6943 - val_precision: 0.8042 - val_recall: 0.5959 - val_auc: 0.9313 - val_auc_1: 0.7846
# Epoch 7/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.6343 - accuracy: 0.7658 - precision: 0.8339 - recall: 0.6934 - auc: 0.9659 - auc_1: 0.8631 - val_loss: 0.6177 - val_accuracy: 0.7876 - val_precision: 0.8986 - val_recall: 0.6891 - val_auc: 0.9703 - val_auc_1: 0.8832
# Epoch 8/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.6147 - accuracy: 0.7737 - precision: 0.8394 - recall: 0.7073 - auc: 0.9676 - auc_1: 0.8704 - val_loss: 0.8297 - val_accuracy: 0.7150 - val_precision: 0.7844 - val_recall: 0.6788 - val_auc: 0.9498 - val_auc_1: 0.8216
# Epoch 9/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.6227 - accuracy: 0.7686 - precision: 0.8346 - recall: 0.7031 - auc: 0.9668 - auc_1: 0.8667 - val_loss: 0.6322 - val_accuracy: 0.7668 - val_precision: 0.8199 - val_recall: 0.6839 - val_auc: 0.9658 - val_auc_1: 0.8625
# Epoch 10/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.5909 - accuracy: 0.7797 - precision: 0.8408 - recall: 0.7214 - auc: 0.9699 - auc_1: 0.8770 - val_loss: 0.7435 - val_accuracy: 0.7306 - val_precision: 0.7736 - val_recall: 0.6373 - val_auc: 0.9558 - val_auc_1: 0.8292
# Epoch 11/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.5933 - accuracy: 0.7763 - precision: 0.8372 - recall: 0.7158 - auc: 0.9698 - auc_1: 0.8760 - val_loss: 0.6342 - val_accuracy: 0.7824 - val_precision: 0.8654 - val_recall: 0.6995 - val_auc: 0.9662 - val_auc_1: 0.8688
# Epoch 12/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.5731 - accuracy: 0.7876 - precision: 0.8430 - recall: 0.7254 - auc: 0.9717 - auc_1: 0.8819 - val_loss: 0.7465 - val_accuracy: 0.7306 - val_precision: 0.8267 - val_recall: 0.6425 - val_auc: 0.9540 - val_auc_1: 0.8234
# Epoch 13/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.5670 - accuracy: 0.7919 - precision: 0.8512 - recall: 0.7318 - auc: 0.9724 - auc_1: 0.8849 - val_loss: 0.6853 - val_accuracy: 0.7565 - val_precision: 0.8144 - val_recall: 0.7047 - val_auc: 0.9616 - val_auc_1: 0.8547
# Epoch 14/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.5447 - accuracy: 0.7955 - precision: 0.8469 - recall: 0.7466 - auc: 0.9744 - auc_1: 0.8918 - val_loss: 0.7930 - val_accuracy: 0.7098 - val_precision: 0.7654 - val_recall: 0.6425 - val_auc: 0.9483 - val_auc_1: 0.8229
# Epoch 15/150
# 81/81 [==============================] - ETA: 0s - loss: 0.5511 - accuracy: 0.7978 - precision: 0.8506 - recall: 0.7380 - auc: 0.9737 - auc_1: 0.8908Restoring model weights from the end of the best epoch: 7.
# 81/81 [==============================] - 152s 2s/step - loss: 0.5511 - accuracy: 0.7978 - precision: 0.8506 - recall: 0.7380 - auc: 0.9737 - auc_1: 0.8908 - val_loss: 0.9037 - val_accuracy: 0.7047 - val_precision: 0.7333 - val_recall: 0.6839 - val_auc: 0.9450 - val_auc_1: 0.8133
# Epoch 00015: early stopping

# %%
eval_val_loss = model_val_loss.evaluate(testgenerator) #early stopping - val_loss
# Out:
# 20/20 [==============================] - 27s 1s/step - loss: 0.7587 - accuracy: 0.7320 - precision: 0.8295 - recall: 0.6420 - auc: 0.9514 - auc_1: 0.8196

# %%
history_df_1 = pd.DataFrame(history_val_loss.history)
from google.colab import files
history_df_1.to_csv('history_val_loss.csv')
files.download('history_val_loss.csv')

# %%
files.download('history_val_loss.csv')

# %% [markdown]
# Minimize val_loss - with class weights

# %%
model_val_loss_weighted = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=8, mode='min',restore_best_weights=True, verbose=1)
history_val_loss_weighted = model_val_loss_weighted.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback], class_weight=class_weight)
# Out:
# Epoch 1/150
# 81/81 [==============================] - 158s 2s/step - loss: 0.1100 - accuracy: 0.3978 - precision_1: 0.6207 - recall_1: 0.2515 - auc_2: 0.7965 - auc_3: 0.4693 - val_loss: 2.1870 - val_accuracy: 0.0415 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_2: 0.4264 - val_auc_3: 0.1157
# Epoch 2/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.0985 - accuracy: 0.4837 - precision_1: 0.6796 - recall_1: 0.3345 - auc_2: 0.8547 - auc_3: 0.5678 - val_loss: 1.9625 - val_accuracy: 0.0104 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_2: 0.6229 - val_auc_3: 0.1710
# Epoch 3/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.0918 - accuracy: 0.4923 - precision_1: 0.6861 - recall_1: 0.3735 - auc_2: 0.8612 - auc_3: 0.5963 - val_loss: 3.6661 - val_accuracy: 0.0725 - val_precision_1: 0.1296 - val_recall_1: 0.0725 - val_auc_2: 0.3965 - val_auc_3: 0.1172
# Epoch 4/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.0873 - accuracy: 0.5072 - precision_1: 0.6869 - recall_1: 0.3753 - auc_2: 0.8741 - auc_3: 0.6116 - val_loss: 2.5560 - val_accuracy: 0.0363 - val_precision_1: 0.0152 - val_recall_1: 0.0052 - val_auc_2: 0.4905 - val_auc_3: 0.1254
# Epoch 5/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.0870 - accuracy: 0.5250 - precision_1: 0.7031 - recall_1: 0.3847 - auc_2: 0.8826 - auc_3: 0.6324 - val_loss: 2.3926 - val_accuracy: 0.1606 - val_precision_1: 0.2083 - val_recall_1: 0.0259 - val_auc_2: 0.5053 - val_auc_3: 0.1516
# Epoch 6/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.0815 - accuracy: 0.5173 - precision_1: 0.6570 - recall_1: 0.3898 - auc_2: 0.8793 - auc_3: 0.6081 - val_loss: 1.7283 - val_accuracy: 0.4456 - val_precision_1: 0.6875 - val_recall_1: 0.3420 - val_auc_2: 0.7710 - val_auc_3: 0.4908
# Epoch 7/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.0817 - accuracy: 0.5185 - precision_1: 0.6588 - recall_1: 0.3985 - auc_2: 0.8836 - auc_3: 0.6210 - val_loss: 1.1991 - val_accuracy: 0.5389 - val_precision_1: 0.7523 - val_recall_1: 0.4249 - val_auc_2: 0.8769 - val_auc_3: 0.6687
# Epoch 8/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.0799 - accuracy: 0.5456 - precision_1: 0.6907 - recall_1: 0.4177 - auc_2: 0.8944 - auc_3: 0.6474 - val_loss: 0.8936 - val_accuracy: 0.6632 - val_precision_1: 0.8359 - val_recall_1: 0.5544 - val_auc_2: 0.9325 - val_auc_3: 0.7848
# Epoch 9/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.0758 - accuracy: 0.5673 - precision_1: 0.7070 - recall_1: 0.4438 - auc_2: 0.9017 - auc_3: 0.6685 - val_loss: 0.9438 - val_accuracy: 0.6373 - val_precision_1: 0.7338 - val_recall_1: 0.5285 - val_auc_2: 0.9260 - val_auc_3: 0.7459
# Epoch 10/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.0755 - accuracy: 0.5692 - precision_1: 0.7009 - recall_1: 0.4603 - auc_2: 0.9051 - auc_3: 0.6807 - val_loss: 1.4049 - val_accuracy: 0.4819 - val_precision_1: 0.6087 - val_recall_1: 0.3627 - val_auc_2: 0.8319 - val_auc_3: 0.5205
# Epoch 11/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.0717 - accuracy: 0.5782 - precision_1: 0.6945 - recall_1: 0.4705 - auc_2: 0.9080 - auc_3: 0.6815 - val_loss: 0.9128 - val_accuracy: 0.6632 - val_precision_1: 0.7554 - val_recall_1: 0.5440 - val_auc_2: 0.9306 - val_auc_3: 0.7553
# Epoch 12/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.0713 - accuracy: 0.5853 - precision_1: 0.6975 - recall_1: 0.4757 - auc_2: 0.9119 - auc_3: 0.6925 - val_loss: 1.4315 - val_accuracy: 0.4715 - val_precision_1: 0.6283 - val_recall_1: 0.3679 - val_auc_2: 0.8392 - val_auc_3: 0.5760
# Epoch 13/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.0697 - accuracy: 0.5903 - precision_1: 0.6945 - recall_1: 0.4870 - auc_2: 0.9147 - auc_3: 0.6948 - val_loss: 1.1357 - val_accuracy: 0.5855 - val_precision_1: 0.6531 - val_recall_1: 0.4974 - val_auc_2: 0.8958 - val_auc_3: 0.6466
# Epoch 14/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.0692 - accuracy: 0.5783 - precision_1: 0.6925 - recall_1: 0.4724 - auc_2: 0.9082 - auc_3: 0.6844 - val_loss: 1.6899 - val_accuracy: 0.4041 - val_precision_1: 0.5154 - val_recall_1: 0.3472 - val_auc_2: 0.7927 - val_auc_3: 0.4398
# Epoch 15/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.0759 - accuracy: 0.5661 - precision_1: 0.6820 - recall_1: 0.4525 - auc_2: 0.9037 - auc_3: 0.6702 - val_loss: 2.1822 - val_accuracy: 0.2383 - val_precision_1: 0.2609 - val_recall_1: 0.1554 - val_auc_2: 0.7258 - val_auc_3: 0.2544
# Epoch 16/150
# 81/81 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.5250 - precision_1: 0.7053 - recall_1: 0.3810 - auc_2: 0.8741 - auc_3: 0.6104Restoring model weights from the end of the best epoch: 8.
# 81/81 [==============================] - 153s 2s/step - loss: 0.0902 - accuracy: 0.5250 - precision_1: 0.7053 - recall_1: 0.3810 - auc_2: 0.8741 - auc_3: 0.6104 - val_loss: 1.7742 - val_accuracy: 0.3316 - val_precision_1: 0.4216 - val_recall_1: 0.2228 - val_auc_2: 0.7582 - val_auc_3: 0.3371
# Epoch 00016: early stopping

# %%
eval_val_loss_weighted = model_val_loss_weighted.evaluate(testgenerator) #early stopping - val_loss
# Out:
# 20/20 [==============================] - 27s 1s/step - loss: 0.8770 - accuracy: 0.6605 - precision_1: 0.8255 - recall_1: 0.5700 - auc_2: 0.9356 - auc_3: 0.7804

# %%
history_df_2 = pd.DataFrame(history_val_loss_weighted.history)
from google.colab import files
history_df_2.to_csv('history_val_loss_weighted.csv')
files.download('history_val_loss_weighted.csv')

# %% [markdown]
# Maximize val_accuracy

# %%
model_val_accuracy = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=8, mode='max',restore_best_weights=True, verbose=1)
history_val_accuracy = model_val_accuracy.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 81/81 [==============================] - 157s 2s/step - loss: 0.8771 - accuracy: 0.6853 - precision_2: 0.7990 - recall_2: 0.5910 - auc_4: 0.9353 - auc_5: 0.7807 - val_loss: 1.8597 - val_accuracy: 0.1295 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_4: 0.5534 - val_auc_5: 0.1492
# Epoch 2/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.7566 - accuracy: 0.7189 - precision_2: 0.8247 - recall_2: 0.6276 - auc_4: 0.9516 - auc_5: 0.8222 - val_loss: 1.5645 - val_accuracy: 0.2124 - val_precision_2: 0.2424 - val_recall_2: 0.0415 - val_auc_4: 0.7813 - val_auc_5: 0.2856
# Epoch 3/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.7181 - accuracy: 0.7323 - precision_2: 0.8296 - recall_2: 0.6440 - auc_4: 0.9561 - auc_5: 0.8345 - val_loss: 1.5531 - val_accuracy: 0.1140 - val_precision_2: 0.1583 - val_recall_2: 0.0984 - val_auc_4: 0.8059 - val_auc_5: 0.3104
# Epoch 4/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.6776 - accuracy: 0.7462 - precision_2: 0.8340 - recall_2: 0.6695 - auc_4: 0.9612 - auc_5: 0.8489 - val_loss: 1.1648 - val_accuracy: 0.5855 - val_precision_2: 0.7170 - val_recall_2: 0.3938 - val_auc_4: 0.8874 - val_auc_5: 0.6338
# Epoch 5/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.6729 - accuracy: 0.7532 - precision_2: 0.8319 - recall_2: 0.6731 - auc_4: 0.9614 - auc_5: 0.8516 - val_loss: 1.1112 - val_accuracy: 0.5751 - val_precision_2: 0.7241 - val_recall_2: 0.4352 - val_auc_4: 0.8934 - val_auc_5: 0.6837
# Epoch 6/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.6486 - accuracy: 0.7577 - precision_2: 0.8353 - recall_2: 0.6821 - auc_4: 0.9642 - auc_5: 0.8577 - val_loss: 1.0052 - val_accuracy: 0.6528 - val_precision_2: 0.6971 - val_recall_2: 0.6321 - val_auc_4: 0.9248 - val_auc_5: 0.7457
# Epoch 7/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.6278 - accuracy: 0.7691 - precision_2: 0.8364 - recall_2: 0.6969 - auc_4: 0.9664 - auc_5: 0.8661 - val_loss: 0.8250 - val_accuracy: 0.7306 - val_precision_2: 0.7586 - val_recall_2: 0.6839 - val_auc_4: 0.9492 - val_auc_5: 0.8267
# Epoch 8/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.6260 - accuracy: 0.7652 - precision_2: 0.8374 - recall_2: 0.7008 - auc_4: 0.9668 - auc_5: 0.8649 - val_loss: 0.7597 - val_accuracy: 0.7254 - val_precision_2: 0.7558 - val_recall_2: 0.6736 - val_auc_4: 0.9506 - val_auc_5: 0.8296
# Epoch 9/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.6059 - accuracy: 0.7758 - precision_2: 0.8388 - recall_2: 0.7097 - auc_4: 0.9685 - auc_5: 0.8720 - val_loss: 0.6852 - val_accuracy: 0.7772 - val_precision_2: 0.8079 - val_recall_2: 0.7409 - val_auc_4: 0.9614 - val_auc_5: 0.8705
# Epoch 10/150
# 81/81 [==============================] - 155s 2s/step - loss: 0.5965 - accuracy: 0.7793 - precision_2: 0.8389 - recall_2: 0.7204 - auc_4: 0.9695 - auc_5: 0.8766 - val_loss: 0.7004 - val_accuracy: 0.7254 - val_precision_2: 0.8224 - val_recall_2: 0.6477 - val_auc_4: 0.9574 - val_auc_5: 0.8490
# Epoch 11/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.5800 - accuracy: 0.7827 - precision_2: 0.8446 - recall_2: 0.7201 - auc_4: 0.9711 - auc_5: 0.8795 - val_loss: 0.6695 - val_accuracy: 0.7409 - val_precision_2: 0.8072 - val_recall_2: 0.6943 - val_auc_4: 0.9653 - val_auc_5: 0.8609
# Epoch 12/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.5838 - accuracy: 0.7843 - precision_2: 0.8395 - recall_2: 0.7271 - auc_4: 0.9705 - auc_5: 0.8802 - val_loss: 0.6723 - val_accuracy: 0.7824 - val_precision_2: 0.8354 - val_recall_2: 0.6839 - val_auc_4: 0.9609 - val_auc_5: 0.8638
# Epoch 13/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.5708 - accuracy: 0.7864 - precision_2: 0.8454 - recall_2: 0.7255 - auc_4: 0.9720 - auc_5: 0.8833 - val_loss: 0.6960 - val_accuracy: 0.7254 - val_precision_2: 0.7692 - val_recall_2: 0.6736 - val_auc_4: 0.9600 - val_auc_5: 0.8463
# Epoch 14/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.5516 - accuracy: 0.7954 - precision_2: 0.8455 - recall_2: 0.7437 - auc_4: 0.9738 - auc_5: 0.8908 - val_loss: 0.6241 - val_accuracy: 0.7565 - val_precision_2: 0.7866 - val_recall_2: 0.6684 - val_auc_4: 0.9650 - val_auc_5: 0.8650
# Epoch 15/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.5371 - accuracy: 0.7980 - precision_2: 0.8521 - recall_2: 0.7487 - auc_4: 0.9751 - auc_5: 0.8949 - val_loss: 0.9120 - val_accuracy: 0.7254 - val_precision_2: 0.7472 - val_recall_2: 0.6891 - val_auc_4: 0.9381 - val_auc_5: 0.7969
# Epoch 16/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.5306 - accuracy: 0.8031 - precision_2: 0.8519 - recall_2: 0.7510 - auc_4: 0.9755 - auc_5: 0.8965 - val_loss: 0.6744 - val_accuracy: 0.7668 - val_precision_2: 0.8036 - val_recall_2: 0.6995 - val_auc_4: 0.9636 - val_auc_5: 0.8603
# Epoch 17/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.5046 - accuracy: 0.8126 - precision_2: 0.8542 - recall_2: 0.7747 - auc_4: 0.9778 - auc_5: 0.9041 - val_loss: 0.9546 - val_accuracy: 0.7047 - val_precision_2: 0.7444 - val_recall_2: 0.6943 - val_auc_4: 0.9511 - val_auc_5: 0.8402
# Epoch 18/150
# 81/81 [==============================] - 153s 2s/step - loss: 0.5001 - accuracy: 0.8127 - precision_2: 0.8554 - recall_2: 0.7697 - auc_4: 0.9783 - auc_5: 0.9053 - val_loss: 0.6342 - val_accuracy: 0.7668 - val_precision_2: 0.7874 - val_recall_2: 0.7098 - val_auc_4: 0.9681 - val_auc_5: 0.8663
# Epoch 19/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.4965 - accuracy: 0.8140 - precision_2: 0.8557 - recall_2: 0.7782 - auc_4: 0.9785 - auc_5: 0.9069 - val_loss: 0.8155 - val_accuracy: 0.7202 - val_precision_2: 0.7784 - val_recall_2: 0.7098 - val_auc_4: 0.9573 - val_auc_5: 0.8458
# Epoch 20/150
# 81/81 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.8158 - precision_2: 0.8606 - recall_2: 0.7743 - auc_4: 0.9784 - auc_5: 0.9058Restoring model weights from the end of the best epoch: 12.
# 81/81 [==============================] - 153s 2s/step - loss: 0.4976 - accuracy: 0.8158 - precision_2: 0.8606 - recall_2: 0.7743 - auc_4: 0.9784 - auc_5: 0.9058 - val_loss: 0.6369 - val_accuracy: 0.7565 - val_precision_2: 0.7740 - val_recall_2: 0.7098 - val_auc_4: 0.9668 - val_auc_5: 0.8737
# Epoch 00020: early stopping

# %%
eval_val_accuracy = model_val_accuracy.evaluate(testgenerator) #early stopping - val_accuracy
# Out:
# 20/20 [==============================] - 28s 1s/step - loss: 0.8815 - accuracy: 0.7365 - precision_2: 0.7997 - recall_2: 0.6965 - auc_4: 0.9467 - auc_5: 0.8243

# %%
history_df_3 = pd.DataFrame(history_val_accuracy.history)
from google.colab import files
history_df_3.to_csv('history_val_accuracy.csv')
files.download('history_val_accuracy.csv')

# %% [markdown]
# Maximize val_accuracy - with class weights

# %%
model_val_accuracy_weighted = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=8, mode='max',restore_best_weights=True, verbose=1)
history_val_accuracy_weighted = model_val_accuracy_weighted.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.8846 - accuracy: 0.6764 - precision: 0.8044 - recall: 0.5742 - auc: 0.9339 - auc_1: 0.7763 - val_loss: 1.6875 - val_accuracy: 0.2539 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7528 - val_auc_1: 0.3074
# Epoch 2/150
# 81/81 [==============================] - 146s 2s/step - loss: 0.7533 - accuracy: 0.7173 - precision: 0.8271 - recall: 0.6196 - auc: 0.9522 - auc_1: 0.8237 - val_loss: 1.4907 - val_accuracy: 0.3316 - val_precision: 1.0000 - val_recall: 0.0674 - val_auc: 0.8119 - val_auc_1: 0.4407
# Epoch 3/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.7117 - accuracy: 0.7355 - precision: 0.8266 - recall: 0.6482 - auc: 0.9569 - auc_1: 0.8374 - val_loss: 1.6287 - val_accuracy: 0.3886 - val_precision: 0.2083 - val_recall: 0.0259 - val_auc: 0.7820 - val_auc_1: 0.3533
# Epoch 4/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.6938 - accuracy: 0.7445 - precision: 0.8308 - recall: 0.6606 - auc: 0.9591 - auc_1: 0.8435 - val_loss: 1.3751 - val_accuracy: 0.4819 - val_precision: 0.6818 - val_recall: 0.1554 - val_auc: 0.8405 - val_auc_1: 0.4841
# Epoch 5/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.6782 - accuracy: 0.7498 - precision: 0.8339 - recall: 0.6716 - auc: 0.9611 - auc_1: 0.8485 - val_loss: 1.6226 - val_accuracy: 0.4819 - val_precision: 0.5814 - val_recall: 0.3886 - val_auc: 0.7937 - val_auc_1: 0.5478
# Epoch 6/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.6513 - accuracy: 0.7585 - precision: 0.8314 - recall: 0.6873 - auc: 0.9636 - auc_1: 0.8577 - val_loss: 0.9186 - val_accuracy: 0.6321 - val_precision: 0.8080 - val_recall: 0.5233 - val_auc: 0.9297 - val_auc_1: 0.7470
# Epoch 7/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.6442 - accuracy: 0.7617 - precision: 0.8361 - recall: 0.6875 - auc: 0.9647 - auc_1: 0.8607 - val_loss: 1.3672 - val_accuracy: 0.6632 - val_precision: 0.6851 - val_recall: 0.6425 - val_auc: 0.8866 - val_auc_1: 0.7305
# Epoch 8/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.6241 - accuracy: 0.7708 - precision: 0.8404 - recall: 0.6998 - auc: 0.9667 - auc_1: 0.8668 - val_loss: 0.8386 - val_accuracy: 0.6788 - val_precision: 0.7838 - val_recall: 0.6010 - val_auc: 0.9440 - val_auc_1: 0.8051
# Epoch 9/150
# 81/81 [==============================] - 146s 2s/step - loss: 0.6300 - accuracy: 0.7694 - precision: 0.8359 - recall: 0.7023 - auc: 0.9661 - auc_1: 0.8646 - val_loss: 0.8112 - val_accuracy: 0.6839 - val_precision: 0.8345 - val_recall: 0.6010 - val_auc: 0.9431 - val_auc_1: 0.8003
# Epoch 10/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.6035 - accuracy: 0.7739 - precision: 0.8370 - recall: 0.7122 - auc: 0.9689 - auc_1: 0.8728 - val_loss: 0.8576 - val_accuracy: 0.7047 - val_precision: 0.7692 - val_recall: 0.5699 - val_auc: 0.9388 - val_auc_1: 0.7676
# Epoch 11/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.5944 - accuracy: 0.7742 - precision: 0.8358 - recall: 0.7164 - auc: 0.9699 - auc_1: 0.8752 - val_loss: 0.8295 - val_accuracy: 0.7047 - val_precision: 0.7669 - val_recall: 0.6477 - val_auc: 0.9438 - val_auc_1: 0.8001
# Epoch 12/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.5743 - accuracy: 0.7812 - precision: 0.8435 - recall: 0.7234 - auc: 0.9717 - auc_1: 0.8822 - val_loss: 0.5961 - val_accuracy: 0.7824 - val_precision: 0.8535 - val_recall: 0.6943 - val_auc: 0.9693 - val_auc_1: 0.8821
# Epoch 13/150
# 81/81 [==============================] - 146s 2s/step - loss: 0.5734 - accuracy: 0.7832 - precision: 0.8412 - recall: 0.7230 - auc: 0.9718 - auc_1: 0.8820 - val_loss: 0.6687 - val_accuracy: 0.7565 - val_precision: 0.8284 - val_recall: 0.7254 - val_auc: 0.9627 - val_auc_1: 0.8605
# Epoch 14/150
# 81/81 [==============================] - 146s 2s/step - loss: 0.5557 - accuracy: 0.7895 - precision: 0.8437 - recall: 0.7404 - auc: 0.9734 - auc_1: 0.8878 - val_loss: 0.7190 - val_accuracy: 0.7202 - val_precision: 0.7719 - val_recall: 0.6839 - val_auc: 0.9594 - val_auc_1: 0.8587
# Epoch 15/150
# 81/81 [==============================] - 146s 2s/step - loss: 0.5610 - accuracy: 0.7933 - precision: 0.8505 - recall: 0.7351 - auc: 0.9729 - auc_1: 0.8875 - val_loss: 0.8123 - val_accuracy: 0.6995 - val_precision: 0.7456 - val_recall: 0.6528 - val_auc: 0.9485 - val_auc_1: 0.7911
# Epoch 16/150
# 81/81 [==============================] - 146s 2s/step - loss: 0.5330 - accuracy: 0.7976 - precision: 0.8489 - recall: 0.7502 - auc: 0.9755 - auc_1: 0.8948 - val_loss: 0.6501 - val_accuracy: 0.7617 - val_precision: 0.8125 - val_recall: 0.7409 - val_auc: 0.9652 - val_auc_1: 0.8727
# Epoch 17/150
# 81/81 [==============================] - 146s 2s/step - loss: 0.5189 - accuracy: 0.8011 - precision: 0.8513 - recall: 0.7601 - auc: 0.9767 - auc_1: 0.8997 - val_loss: 0.5871 - val_accuracy: 0.7617 - val_precision: 0.8364 - val_recall: 0.7150 - val_auc: 0.9698 - val_auc_1: 0.8850
# Epoch 18/150
# 81/81 [==============================] - 150s 2s/step - loss: 0.5239 - accuracy: 0.8034 - precision: 0.8529 - recall: 0.7538 - auc: 0.9762 - auc_1: 0.8974 - val_loss: 0.9646 - val_accuracy: 0.6839 - val_precision: 0.7160 - val_recall: 0.6269 - val_auc: 0.9266 - val_auc_1: 0.7247
# Epoch 19/150
# 81/81 [==============================] - 146s 2s/step - loss: 0.5177 - accuracy: 0.8057 - precision: 0.8549 - recall: 0.7571 - auc: 0.9767 - auc_1: 0.9002 - val_loss: 0.7222 - val_accuracy: 0.7306 - val_precision: 0.7826 - val_recall: 0.6528 - val_auc: 0.9562 - val_auc_1: 0.8396
# Epoch 20/150
# 81/81 [==============================] - ETA: 0s - loss: 0.4977 - accuracy: 0.8086 - precision: 0.8536 - recall: 0.7651 - auc: 0.9786 - auc_1: 0.9054Restoring model weights from the end of the best epoch: 12.
# 81/81 [==============================] - 145s 2s/step - loss: 0.4977 - accuracy: 0.8086 - precision: 0.8536 - recall: 0.7651 - auc: 0.9786 - auc_1: 0.9054 - val_loss: 0.6955 - val_accuracy: 0.7409 - val_precision: 0.8217 - val_recall: 0.6684 - val_auc: 0.9621 - val_auc_1: 0.8512
# Epoch 00020: early stopping

# %%
eval_val_accuracy_weighted = model_val_accuracy_weighted.evaluate(testgenerator) #early stopping - val_accuracy
# Out:
# 20/20 [==============================] - 30s 2s/step - loss: 0.6659 - accuracy: 0.7550 - precision: 0.8236 - recall: 0.6955 - auc: 0.9631 - auc_1: 0.8584

# %%
history_df_4 = pd.DataFrame(history_val_accuracy_weighted.history)
from google.colab import files
history_df_4.to_csv('history_val_accuracy_weighted.csv')
files.download('history_val_accuracy_weighted.csv')

# %% [markdown]
# Maximize val_recall

# %%
model_val_recall = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_recall', patience=8, mode='max',restore_best_weights=True, verbose=1)
history_val_recall = model_val_recall.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 81/81 [==============================] - 157s 2s/step - loss: 0.8862 - accuracy: 0.6818 - precision: 0.8020 - recall: 0.5793 - auc: 0.9337 - auc_1: 0.7769 - val_loss: 1.5832 - val_accuracy: 0.6321 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8284 - val_auc_1: 0.5319
# Epoch 2/150
# 81/81 [==============================] - 150s 2s/step - loss: 0.7665 - accuracy: 0.7152 - precision: 0.8225 - recall: 0.6170 - auc: 0.9502 - auc_1: 0.8170 - val_loss: 1.7399 - val_accuracy: 0.1710 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7100 - val_auc_1: 0.2320
# Epoch 3/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.7162 - accuracy: 0.7347 - precision: 0.8267 - recall: 0.6518 - auc: 0.9563 - auc_1: 0.8355 - val_loss: 1.8036 - val_accuracy: 0.1762 - val_precision: 0.1753 - val_recall: 0.0881 - val_auc: 0.7583 - val_auc_1: 0.2753
# Epoch 4/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.6945 - accuracy: 0.7431 - precision: 0.8281 - recall: 0.6634 - auc: 0.9590 - auc_1: 0.8424 - val_loss: 1.5725 - val_accuracy: 0.4560 - val_precision: 0.4250 - val_recall: 0.0881 - val_auc: 0.7865 - val_auc_1: 0.3849
# Epoch 5/150
# 81/81 [==============================] - 151s 2s/step - loss: 0.6839 - accuracy: 0.7454 - precision: 0.8328 - recall: 0.6605 - auc: 0.9604 - auc_1: 0.8463 - val_loss: 1.1163 - val_accuracy: 0.6166 - val_precision: 0.8447 - val_recall: 0.4508 - val_auc: 0.8874 - val_auc_1: 0.7090
# Epoch 6/150
# 81/81 [==============================] - 150s 2s/step - loss: 0.6534 - accuracy: 0.7560 - precision: 0.8396 - recall: 0.6811 - auc: 0.9635 - auc_1: 0.8567 - val_loss: 0.9062 - val_accuracy: 0.7047 - val_precision: 0.8074 - val_recall: 0.5648 - val_auc: 0.9287 - val_auc_1: 0.7843
# Epoch 7/150
# 81/81 [==============================] - 156s 2s/step - loss: 0.6472 - accuracy: 0.7587 - precision: 0.8295 - recall: 0.6857 - auc: 0.9644 - auc_1: 0.8582 - val_loss: 0.7000 - val_accuracy: 0.7461 - val_precision: 0.8113 - val_recall: 0.6684 - val_auc: 0.9594 - val_auc_1: 0.8419
# Epoch 8/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.6194 - accuracy: 0.7703 - precision: 0.8421 - recall: 0.7013 - auc: 0.9670 - auc_1: 0.8686 - val_loss: 0.7172 - val_accuracy: 0.7409 - val_precision: 0.8915 - val_recall: 0.5959 - val_auc: 0.9570 - val_auc_1: 0.8451
# Epoch 9/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.6221 - accuracy: 0.7684 - precision: 0.8402 - recall: 0.7024 - auc: 0.9668 - auc_1: 0.8664 - val_loss: 0.8930 - val_accuracy: 0.6839 - val_precision: 0.8309 - val_recall: 0.5855 - val_auc: 0.9336 - val_auc_1: 0.7897
# Epoch 10/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.5863 - accuracy: 0.7808 - precision: 0.8448 - recall: 0.7249 - auc: 0.9704 - auc_1: 0.8789 - val_loss: 0.5797 - val_accuracy: 0.7720 - val_precision: 0.8250 - val_recall: 0.6839 - val_auc: 0.9718 - val_auc_1: 0.8805
# Epoch 11/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.5912 - accuracy: 0.7733 - precision: 0.8383 - recall: 0.7147 - auc: 0.9702 - auc_1: 0.8763 - val_loss: 0.7087 - val_accuracy: 0.7202 - val_precision: 0.8312 - val_recall: 0.6632 - val_auc: 0.9572 - val_auc_1: 0.8397
# Epoch 12/150
# 81/81 [==============================] - 150s 2s/step - loss: 0.5870 - accuracy: 0.7773 - precision: 0.8402 - recall: 0.7204 - auc: 0.9704 - auc_1: 0.8776 - val_loss: 0.8116 - val_accuracy: 0.7202 - val_precision: 0.7658 - val_recall: 0.6269 - val_auc: 0.9468 - val_auc_1: 0.7920
# Epoch 13/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.5640 - accuracy: 0.7868 - precision: 0.8449 - recall: 0.7294 - auc: 0.9727 - auc_1: 0.8850 - val_loss: 0.7657 - val_accuracy: 0.7098 - val_precision: 0.7778 - val_recall: 0.6891 - val_auc: 0.9576 - val_auc_1: 0.8377
# Epoch 14/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.5533 - accuracy: 0.7915 - precision: 0.8416 - recall: 0.7432 - auc: 0.9735 - auc_1: 0.8894 - val_loss: 0.5591 - val_accuracy: 0.7876 - val_precision: 0.8457 - val_recall: 0.7098 - val_auc: 0.9728 - val_auc_1: 0.8889
# Epoch 15/150
# 81/81 [==============================] - 150s 2s/step - loss: 0.5453 - accuracy: 0.7968 - precision: 0.8494 - recall: 0.7412 - auc: 0.9744 - auc_1: 0.8919 - val_loss: 0.5930 - val_accuracy: 0.7668 - val_precision: 0.8434 - val_recall: 0.7254 - val_auc: 0.9707 - val_auc_1: 0.8833
# Epoch 16/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.5194 - accuracy: 0.8031 - precision: 0.8539 - recall: 0.7582 - auc: 0.9768 - auc_1: 0.8996 - val_loss: 0.5874 - val_accuracy: 0.7565 - val_precision: 0.8114 - val_recall: 0.7358 - val_auc: 0.9725 - val_auc_1: 0.8808
# Epoch 17/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.5140 - accuracy: 0.8085 - precision: 0.8531 - recall: 0.7628 - auc: 0.9771 - auc_1: 0.9013 - val_loss: 0.5809 - val_accuracy: 0.7824 - val_precision: 0.8765 - val_recall: 0.7358 - val_auc: 0.9711 - val_auc_1: 0.8869
# Epoch 18/150
# 81/81 [==============================] - 155s 2s/step - loss: 0.5265 - accuracy: 0.8011 - precision: 0.8545 - recall: 0.7497 - auc: 0.9760 - auc_1: 0.8971 - val_loss: 0.6908 - val_accuracy: 0.7358 - val_precision: 0.8228 - val_recall: 0.6736 - val_auc: 0.9599 - val_auc_1: 0.8373
# Epoch 19/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.5100 - accuracy: 0.8057 - precision: 0.8534 - recall: 0.7626 - auc: 0.9775 - auc_1: 0.9017 - val_loss: 0.6141 - val_accuracy: 0.7824 - val_precision: 0.8294 - val_recall: 0.7306 - val_auc: 0.9671 - val_auc_1: 0.8780
# Epoch 20/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.4948 - accuracy: 0.8167 - precision: 0.8584 - recall: 0.7671 - auc: 0.9787 - auc_1: 0.9069 - val_loss: 0.8214 - val_accuracy: 0.7461 - val_precision: 0.7861 - val_recall: 0.7047 - val_auc: 0.9491 - val_auc_1: 0.8288
# Epoch 21/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.4736 - accuracy: 0.8186 - precision: 0.8638 - recall: 0.7802 - auc: 0.9804 - auc_1: 0.9127 - val_loss: 0.6593 - val_accuracy: 0.7565 - val_precision: 0.8072 - val_recall: 0.6943 - val_auc: 0.9632 - val_auc_1: 0.8553
# Epoch 22/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.4697 - accuracy: 0.8281 - precision: 0.8654 - recall: 0.7909 - auc: 0.9805 - auc_1: 0.9143 - val_loss: 0.9969 - val_accuracy: 0.6995 - val_precision: 0.7363 - val_recall: 0.6943 - val_auc: 0.9353 - val_auc_1: 0.7943
# Epoch 23/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.4479 - accuracy: 0.8327 - precision: 0.8647 - recall: 0.7984 - auc: 0.9824 - auc_1: 0.9208 - val_loss: 0.6852 - val_accuracy: 0.7927 - val_precision: 0.8111 - val_recall: 0.7565 - val_auc: 0.9597 - val_auc_1: 0.8733
# Epoch 24/150
# 81/81 [==============================] - 155s 2s/step - loss: 0.4386 - accuracy: 0.8362 - precision: 0.8681 - recall: 0.8039 - auc: 0.9828 - auc_1: 0.9228 - val_loss: 0.8304 - val_accuracy: 0.7668 - val_precision: 0.7861 - val_recall: 0.7617 - val_auc: 0.9477 - val_auc_1: 0.8497
# Epoch 25/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.4430 - accuracy: 0.8313 - precision: 0.8679 - recall: 0.7973 - auc: 0.9828 - auc_1: 0.9215 - val_loss: 0.7111 - val_accuracy: 0.7409 - val_precision: 0.7746 - val_recall: 0.6943 - val_auc: 0.9561 - val_auc_1: 0.8439
# Epoch 26/150
# 81/81 [==============================] - 150s 2s/step - loss: 0.4709 - accuracy: 0.8236 - precision: 0.8620 - recall: 0.7853 - auc: 0.9803 - auc_1: 0.9142 - val_loss: 0.9558 - val_accuracy: 0.7565 - val_precision: 0.7814 - val_recall: 0.7409 - val_auc: 0.9382 - val_auc_1: 0.8019
# Epoch 27/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.4192 - accuracy: 0.8417 - precision: 0.8711 - recall: 0.8115 - auc: 0.9845 - auc_1: 0.9285 - val_loss: 0.9205 - val_accuracy: 0.7098 - val_precision: 0.7472 - val_recall: 0.6891 - val_auc: 0.9394 - val_auc_1: 0.7834
# Epoch 28/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.3955 - accuracy: 0.8455 - precision: 0.8718 - recall: 0.8186 - auc: 0.9862 - auc_1: 0.9353 - val_loss: 0.8679 - val_accuracy: 0.7098 - val_precision: 0.7486 - val_recall: 0.6788 - val_auc: 0.9470 - val_auc_1: 0.8122
# Epoch 29/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.3885 - accuracy: 0.8544 - precision: 0.8783 - recall: 0.8274 - auc: 0.9863 - auc_1: 0.9368 - val_loss: 0.7805 - val_accuracy: 0.7202 - val_precision: 0.7803 - val_recall: 0.6995 - val_auc: 0.9503 - val_auc_1: 0.8304
# Epoch 30/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.3788 - accuracy: 0.8589 - precision: 0.8821 - recall: 0.8338 - auc: 0.9869 - auc_1: 0.9397 - val_loss: 0.6273 - val_accuracy: 0.7772 - val_precision: 0.8136 - val_recall: 0.7461 - val_auc: 0.9680 - val_auc_1: 0.8762
# Epoch 31/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.3812 - accuracy: 0.8541 - precision: 0.8830 - recall: 0.8289 - auc: 0.9866 - auc_1: 0.9384 - val_loss: 0.8143 - val_accuracy: 0.7254 - val_precision: 0.7486 - val_recall: 0.7098 - val_auc: 0.9571 - val_auc_1: 0.8375
# Epoch 32/150
# 81/81 [==============================] - ETA: 0s - loss: 0.3587 - accuracy: 0.8648 - precision: 0.8877 - recall: 0.8405 - auc: 0.9885 - auc_1: 0.9451Restoring model weights from the end of the best epoch: 24.
# 81/81 [==============================] - 148s 2s/step - loss: 0.3587 - accuracy: 0.8648 - precision: 0.8877 - recall: 0.8405 - auc: 0.9885 - auc_1: 0.9451 - val_loss: 0.7161 - val_accuracy: 0.7513 - val_precision: 0.8011 - val_recall: 0.7306 - val_auc: 0.9665 - val_auc_1: 0.8708
# Epoch 00032: early stopping

# %%
eval__val_recall = model_val_recall.evaluate(testgenerator) #early stopping - val_recall
# Out:
# 20/20 [==============================] - 34s 2s/step - loss: 0.8278 - accuracy: 0.7335 - precision: 0.7727 - recall: 0.7155 - auc: 0.9507 - auc_1: 0.8447

# %%
history_df_5 = pd.DataFrame(history_val_recall.history)
from google.colab import files
history_df_5.to_csv('history_val_recall.csv')
files.download('history_val_recall.csv')

# %% [markdown]
# Maximize val_recall - with class weights

# %%
model_val_recall_weighted = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_recall', patience=8, mode='max',restore_best_weights=True, verbose=1)
history_val_recall_weighted = model_val_recall_weighted.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.8621 - accuracy: 0.6845 - precision: 0.8042 - recall: 0.5833 - auc: 0.9372 - auc_1: 0.7845 - val_loss: 1.7889 - val_accuracy: 0.1140 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7587 - val_auc_1: 0.2519
# Epoch 2/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.7586 - accuracy: 0.7138 - precision: 0.8220 - recall: 0.6256 - auc: 0.9514 - auc_1: 0.8203 - val_loss: 1.4840 - val_accuracy: 0.4352 - val_precision: 0.4914 - val_recall: 0.2953 - val_auc: 0.8217 - val_auc_1: 0.4305
# Epoch 3/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.7089 - accuracy: 0.7349 - precision: 0.8247 - recall: 0.6586 - auc: 0.9572 - auc_1: 0.8372 - val_loss: 1.5718 - val_accuracy: 0.5544 - val_precision: 0.3333 - val_recall: 0.0052 - val_auc: 0.8065 - val_auc_1: 0.4418
# Epoch 4/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.6774 - accuracy: 0.7440 - precision: 0.8277 - recall: 0.6689 - auc: 0.9612 - auc_1: 0.8476 - val_loss: 1.2834 - val_accuracy: 0.6632 - val_precision: 0.7383 - val_recall: 0.5699 - val_auc: 0.8619 - val_auc_1: 0.6653
# Epoch 5/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.6849 - accuracy: 0.7460 - precision: 0.8243 - recall: 0.6644 - auc: 0.9603 - auc_1: 0.8450 - val_loss: 1.0053 - val_accuracy: 0.6269 - val_precision: 0.8448 - val_recall: 0.5078 - val_auc: 0.9139 - val_auc_1: 0.7488
# Epoch 6/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.6458 - accuracy: 0.7651 - precision: 0.8311 - recall: 0.6949 - auc: 0.9643 - auc_1: 0.8596 - val_loss: 1.1877 - val_accuracy: 0.5648 - val_precision: 0.6414 - val_recall: 0.4819 - val_auc: 0.8841 - val_auc_1: 0.6462
# Epoch 7/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.6364 - accuracy: 0.7627 - precision: 0.8318 - recall: 0.6966 - auc: 0.9655 - auc_1: 0.8623 - val_loss: 0.6078 - val_accuracy: 0.7876 - val_precision: 0.8323 - val_recall: 0.7202 - val_auc: 0.9684 - val_auc_1: 0.8785
# Epoch 8/150
# 81/81 [==============================] - 146s 2s/step - loss: 0.6135 - accuracy: 0.7732 - precision: 0.8369 - recall: 0.7074 - auc: 0.9677 - auc_1: 0.8709 - val_loss: 0.5913 - val_accuracy: 0.7772 - val_precision: 0.8742 - val_recall: 0.7202 - val_auc: 0.9707 - val_auc_1: 0.8844
# Epoch 9/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.6087 - accuracy: 0.7758 - precision: 0.8410 - recall: 0.7114 - auc: 0.9684 - auc_1: 0.8714 - val_loss: 0.6421 - val_accuracy: 0.7254 - val_precision: 0.8101 - val_recall: 0.6632 - val_auc: 0.9651 - val_auc_1: 0.8582
# Epoch 10/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.6057 - accuracy: 0.7739 - precision: 0.8358 - recall: 0.7107 - auc: 0.9686 - auc_1: 0.8721 - val_loss: 0.6263 - val_accuracy: 0.7617 - val_precision: 0.8239 - val_recall: 0.6788 - val_auc: 0.9676 - val_auc_1: 0.8676
# Epoch 11/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.5842 - accuracy: 0.7793 - precision: 0.8398 - recall: 0.7241 - auc: 0.9707 - auc_1: 0.8789 - val_loss: 0.6743 - val_accuracy: 0.7461 - val_precision: 0.8205 - val_recall: 0.6632 - val_auc: 0.9619 - val_auc_1: 0.8469
# Epoch 12/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.5675 - accuracy: 0.7864 - precision: 0.8456 - recall: 0.7328 - auc: 0.9723 - auc_1: 0.8841 - val_loss: 1.0971 - val_accuracy: 0.6114 - val_precision: 0.7293 - val_recall: 0.5026 - val_auc: 0.9005 - val_auc_1: 0.7085
# Epoch 13/150
# 81/81 [==============================] - 147s 2s/step - loss: 0.5651 - accuracy: 0.7880 - precision: 0.8464 - recall: 0.7308 - auc: 0.9725 - auc_1: 0.8851 - val_loss: 0.6523 - val_accuracy: 0.7306 - val_precision: 0.8158 - val_recall: 0.6425 - val_auc: 0.9622 - val_auc_1: 0.8569
# Epoch 14/150
# 81/81 [==============================] - 155s 2s/step - loss: 0.5571 - accuracy: 0.7904 - precision: 0.8474 - recall: 0.7399 - auc: 0.9734 - auc_1: 0.8883 - val_loss: 0.7909 - val_accuracy: 0.7047 - val_precision: 0.7764 - val_recall: 0.6477 - val_auc: 0.9495 - val_auc_1: 0.8250
# Epoch 15/150
# 81/81 [==============================] - 151s 2s/step - loss: 0.5509 - accuracy: 0.7924 - precision: 0.8509 - recall: 0.7429 - auc: 0.9741 - auc_1: 0.8906 - val_loss: 0.5973 - val_accuracy: 0.7824 - val_precision: 0.8372 - val_recall: 0.7461 - val_auc: 0.9695 - val_auc_1: 0.8882
# Epoch 16/150
# 81/81 [==============================] - 149s 2s/step - loss: 0.5185 - accuracy: 0.8010 - precision: 0.8524 - recall: 0.7536 - auc: 0.9767 - auc_1: 0.8996 - val_loss: 0.8324 - val_accuracy: 0.7150 - val_precision: 0.7925 - val_recall: 0.6528 - val_auc: 0.9443 - val_auc_1: 0.8125
# Epoch 17/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.5213 - accuracy: 0.8026 - precision: 0.8521 - recall: 0.7565 - auc: 0.9764 - auc_1: 0.8994 - val_loss: 0.7038 - val_accuracy: 0.7461 - val_precision: 0.8313 - val_recall: 0.7150 - val_auc: 0.9594 - val_auc_1: 0.8637
# Epoch 18/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.5251 - accuracy: 0.8019 - precision: 0.8517 - recall: 0.7492 - auc: 0.9760 - auc_1: 0.8966 - val_loss: 0.8344 - val_accuracy: 0.7306 - val_precision: 0.7914 - val_recall: 0.6684 - val_auc: 0.9466 - val_auc_1: 0.8277
# Epoch 19/150
# 81/81 [==============================] - 148s 2s/step - loss: 0.5035 - accuracy: 0.8091 - precision: 0.8545 - recall: 0.7633 - auc: 0.9780 - auc_1: 0.9040 - val_loss: 0.7485 - val_accuracy: 0.7254 - val_precision: 0.8072 - val_recall: 0.6943 - val_auc: 0.9559 - val_auc_1: 0.8388
# Epoch 20/150
# 81/81 [==============================] - 154s 2s/step - loss: 0.5205 - accuracy: 0.8017 - precision: 0.8494 - recall: 0.7551 - auc: 0.9767 - auc_1: 0.8993 - val_loss: 0.8053 - val_accuracy: 0.7150 - val_precision: 0.7904 - val_recall: 0.6839 - val_auc: 0.9512 - val_auc_1: 0.8351
# Epoch 21/150
# 81/81 [==============================] - 152s 2s/step - loss: 0.4748 - accuracy: 0.8196 - precision: 0.8575 - recall: 0.7750 - auc: 0.9804 - auc_1: 0.9121 - val_loss: 1.1199 - val_accuracy: 0.5699 - val_precision: 0.6757 - val_recall: 0.5181 - val_auc: 0.9057 - val_auc_1: 0.6866
# Epoch 22/150
# 81/81 [==============================] - 150s 2s/step - loss: 0.4675 - accuracy: 0.8213 - precision: 0.8625 - recall: 0.7832 - auc: 0.9808 - auc_1: 0.9145 - val_loss: 1.0305 - val_accuracy: 0.6995 - val_precision: 0.7697 - val_recall: 0.6580 - val_auc: 0.9279 - val_auc_1: 0.7815
# Epoch 23/150
# 81/81 [==============================] - ETA: 0s - loss: 0.4583 - accuracy: 0.8263 - precision: 0.8644 - recall: 0.7899 - auc: 0.9817 - auc_1: 0.9176Restoring model weights from the end of the best epoch: 15.
# 81/81 [==============================] - 149s 2s/step - loss: 0.4583 - accuracy: 0.8263 - precision: 0.8644 - recall: 0.7899 - auc: 0.9817 - auc_1: 0.9176 - val_loss: 0.6893 - val_accuracy: 0.7461 - val_precision: 0.7943 - val_recall: 0.7202 - val_auc: 0.9595 - val_auc_1: 0.8622
# Epoch 00023: early stopping

# %%
eval__val_recall_weighted = model_val_recall_weighted.evaluate(testgenerator) #early stopping - val_recall
# Out:
# 20/20 [==============================] - 36s 2s/step - loss: 0.6745 - accuracy: 0.7680 - precision: 0.8068 - recall: 0.7350 - auc: 0.9652 - auc_1: 0.8672

# %% [markdown]
# val_loss plots

# %%
history_df_6 = pd.DataFrame(history_val_recall_weighted.history)
from google.colab import files
history_df_6.to_csv('history_val_recall_weighted.csv')
files.download('history_val_recall_weighted.csv')

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_loss.history['accuracy'])
plt.plot(history_val_loss.history['val_accuracy'])
plt.plot(history_val_loss.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])

# %%
plt.plot(history_val_loss.history['loss'])
plt.plot(history_val_loss.history['val_loss'])

# %% [markdown]
# val_loss - weighted

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_loss_weighted.history['accuracy'])
plt.plot(history_val_loss_weighted.history['val_accuracy'])
plt.plot(history_val_loss_weighted.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])

# %%
plt.plot(history_val_loss_weighted.history['loss'])
plt.plot(history_val_loss_weighted.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %% [markdown]
# val_accuracy

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_accuracy.history['accuracy'])
plt.plot(history_val_accuracy.history['val_accuracy'])
plt.plot(history_val_accuracy.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])

# %%
plt.plot(history_val_accuracy.history['loss'])
plt.plot(history_val_accuracy.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %% [markdown]
# val_accuracy - weighted

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_accuracy_weighted.history['accuracy'])
plt.plot(history_val_accuracy_weighted.history['val_accuracy'])
plt.plot(history_val_accuracy_weighted.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])

# %%
plt.plot(history_val_accuracy_weighted.history['loss'])
plt.plot(history_val_accuracy_weighted.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %% [markdown]
# val_recall

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_recall.history['accuracy'])
plt.plot(history_val_recall.history['val_accuracy'])
plt.plot(history_val_recall.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])

# %%
plt.plot(history_val_recall.history['loss'])
plt.plot(history_val_recall.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %% [markdown]
# val_recall - weighted

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_recall_weighted.history['accuracy'])
plt.plot(history_val_recall_weighted.history['val_accuracy'])
plt.plot(history_val_recall_weighted.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])

# %%
plt.plot(history_val_recall_weighted.history['loss'])
plt.plot(history_val_recall_weighted.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %%
np.save('early_stopping__val_loss_custom_weights_history.npy',history.history)

# %%
#history=np.load('50epoch-no_custom_weights_history.npy',allow_pickle='TRUE').item()

# %%
model_val_loss.save("early_stopping__val_loss_custom_weights")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: recall_early_stop-no_custom_weights/assets

# %%
np.save('early_stopping__val_accuracy_custom_weights_history.npy',history.history)

# %%
model_val_accuracy.save("early_stopping__val_accuracy_custom_weights")

# %%
np.save('early_stopping__val_recall_custom_weights_history.npy',history.history)

# %%
model_val_recall.save("early_stopping__val_recall_custom_weights")

# %%
# !zip -r recall_early_stop-no_custom_weights.zip recall_early_stop-no_custom_weights
# Out:
#   adding: recall_early_stop-no_custom_weights/ (stored 0%)
#   adding: recall_early_stop-no_custom_weights/assets/ (stored 0%)
#   adding: recall_early_stop-no_custom_weights/keras_metadata.pb (deflated 93%)
#   adding: recall_early_stop-no_custom_weights/saved_model.pb (deflated 90%)
#   adding: recall_early_stop-no_custom_weights/variables/ (stored 0%)
#   adding: recall_early_stop-no_custom_weights/variables/variables.data-00000-of-00001 (deflated 12%)
#   adding: recall_early_stop-no_custom_weights/variables/variables.index (deflated 73%)

# %%
# !unzip /content/early-stop-val_recall-custom_weights.zip
# Out:
# Archive:  /content/early-stop-val_recall-custom_weights.zip
#    creating: early-stop-val_recall-custom_weights/assets/
#   inflating: early-stop-val_recall-custom_weights/keras_metadata.pb
#   inflating: early-stop-val_recall-custom_weights/saved_model.pb
#    creating: early-stop-val_recall-custom_weights/variables/
#   inflating: early-stop-val_recall-custom_weights/variables/variables.data-00000-of-00001
#   inflating: early-stop-val_recall-custom_weights/variables/variables.index

# %%
# !mv /content/early-stop-val_recall-custom_weights/* /content

# %%
model = tf.keras.models.load_model("early-stop-val_recall-custom_weights")

# %% [markdown]
# List of Convolutional Layers in the model

# %%
for layer in model.layers:
  if 'conv' in layer.name:
    filters, biases = layer.get_weights()
    print(layer.name, filters.shape)
# Out:
# conv2d_24 (3, 3, 3, 16)
# conv2d_25 (3, 3, 16, 32)
# conv2d_26 (3, 3, 32, 64)
# conv2d_27 (3, 3, 64, 64)
# conv2d_28 (3, 3, 64, 128)
# conv2d_29 (3, 3, 128, 128)

# %%
filters, biases = model.layers[0].get_weights()
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)
n_filters, ix = filters.shape[-1], 1
for i in range(n_filters):
  # get the filter
  f = filters[:, :, :, i]
  # plot each channel separately
  for j in range(3):
    # specify subplot and turn of axis
    ax = plt.subplot(n_filters, 3, ix)
    ax.set_xticks([])
    ax.set_yticks([])
    # plot filter channel in grayscale
    plt.imshow(f[:, :, j], cmap='gray')
    ix += 1
# show the figure
plt.show()

# %%
test_file_names = testgenerator.filenames
sample_indexes = []
class_index_keys = list(class_index.keys())
for j in range(len(class_index_keys)):
  for i in range(len(test_file_names)):
    if test_file_names[i][test_file_names[i].find(class_index_keys[j]):len(class_index_keys[j])]: 
      sample_indexes.append(i)
      break

sample_AKIEC = "Train/" + test_file_names[sample_indexes[0]]
sample_BCC   = "Train/" + test_file_names[sample_indexes[1]]
sample_BKL   = "Train/" + test_file_names[sample_indexes[2]]
sample_DF    = "Train/" + test_file_names[sample_indexes[3]]
sample_MEL   = "Train/" + test_file_names[sample_indexes[4]]
sample_NV    = "Train/" + test_file_names[sample_indexes[5]]
sample_VASC  = "Train/" + test_file_names[sample_indexes[6]]

# %%
pyplot.rcParams['figure.figsize'] = [30, 5]

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model
from matplotlib import pyplot
from numpy import expand_dims
# load the model
ixs = [0, 3, 6, 7, 10, 11]
outputs = [model.layers[i+1].output for i in ixs]
model = Model(inputs=model.inputs, outputs=outputs)
# load the image with the required shape
img = load_img(sample_AKIEC, target_size=(75, 100), color_mode='rgb')
# convert the image to an array
img = img_to_array(img)
# expand dimensions so that it represents a single 'sample'
img = expand_dims(img, axis=0)

# get feature map for first hidden layer
feature_maps = model.predict(img)
# plot the output from each block
for fmap in feature_maps:
  # plot all 64 maps in an 8x8 squares
  ix = 1
  dim = fmap.shape[-1]
  #	for _ in range(square):
  for _ in range(dim):
    # specify subplot and turn of axis
    ax = pyplot.subplot(1, dim, ix)
    ax.set_xticks([])
    ax.set_yticks([])
    # plot filter channel in grayscale
    pyplot.imshow(fmap[0, :, :, ix-1])
    ix += 1
	# show the figure
  #pyplot.gcf().set_size_inches(10,50)
  pyplot.show()

# %%
traingenerator.reset()

# %%
x=np.concatenate([traingenerator.next()[0] for i in range(traingenerator.__len__())])
y=np.concatenate([traingenerator.next()[1] for i in range(traingenerator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# (8015, 75, 100, 3)
# (8015, 7)
